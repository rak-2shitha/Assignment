# %% [markdown]
# ## ESTIMATION AND CONFIDENCE INTERVALS

# %% [markdown]
# #### Background
#
# In quality control processes, especially when dealing with high-value items, destructive sampling is a necessary but costly method to ensure product quality. The test to determine whether an item meets the quality standards destroys the item, leading to the requirement of small sample sizes due to cost constraints.

# %% [markdown]
# #### Scenario
#
# A manufacturer of print-heads for personal computers is interested in estimating the mean durability of their print-heads in terms of the number of characters printed before failure. To assess this, the manufacturer conducts a study on a small sample of print-heads due to the destructive nature of the testing process.

# %% [markdown]
# #### Data
#
# A total of 15 print-heads were randomly selected and tested until failure. The durability of each print-head (in millions of characters) was recorded as follows:
#
# 1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29

# %% [markdown]
# #### Assignment Tasks

# %% [markdown]
# ##### a. Build 99% Confidence Interval Using Sample Standard Deviation
#
# Assuming the sample is representative of the population, construct a 99% confidence interval for the mean number of characters printed before the print-head fails using the sample standard deviation. Explain the steps you take and the rationale behind using the t-distribution for this task.

# %%
import numpy as np
import scipy.stats as stats

# %%
data = [1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 
        1.48, 1.20, 1.33, 1.18, 1.22, 1.29]

# %%
n = len(data)
mean = np.mean(data)
std_dev = np.std(data, ddof=1)   # sample standard deviation

# t critical value
t_critical = stats.t.ppf(1 - 0.005, df=n-1)

# margin of error
margin_error = t_critical * (std_dev / np.sqrt(n))

# confidence interval
ci_lower = mean - margin_error
ci_upper = mean + margin_error

print("Mean:", mean)
print("Sample Std Dev:", std_dev)
print("99% CI (t-distribution):", (ci_lower, ci_upper))
# Out:
# Mean: 1.2386666666666666
# Sample Std Dev: 0.19316412956959936
# 99% CI (t-distribution): (np.float64(1.0901973384384906), np.float64(1.3871359948948425))

# %% [markdown]
# ##### We use t-distribution because:
#
# Population standard deviation (σ) is unknown
#
# Sample size is small (n < 30)
#
# t-distribution accounts for extra uncertainty using heavier tails
#
# -> If σ were known, we would use Z-distribution instead

# %% [markdown]
# ##### b. Build 99% Confidence Interval Using Known Population Standard Deviation
#
# If it were known that the population standard deviation is 0.2 million characters, construct a 99% confidence interval for the mean number of characters printed before failure.

# %%
sigma = 0.2  # given population std deviation

# z critical value
z_critical = stats.norm.ppf(1 - 0.005)

# margin of error
margin_error_z = z_critical * (sigma / np.sqrt(n))

# confidence interval
ci_lower_z = mean - margin_error_z
ci_upper_z = mean + margin_error_z

print("99% CI (Z-distribution):", (ci_lower_z, ci_upper_z))
# Out:
# 99% CI (Z-distribution): (np.float64(1.1056514133957607), np.float64(1.3716819199375725))

# %% [markdown]
# ## HYPOTHESIS TESTING

# %% [markdown]
# #### Background:
#
# Bombay hospitality Ltd. operates a franchise model for producing exotic Norwegian dinners throughout New England. The operating cost for a franchise in a week (W) is given by the equation W = $1,000 + $5X, where X represents the number of units produced in a week. Recent feedback from restaurant owners suggests that this cost model may no longer be accurate, as their observed weekly operating costs are higher.

# %% [markdown]
# #### Objective:
#
# To investigate the restaurant owners' claim about the increase in weekly operating costs using hypothesis testing.

# %% [markdown]
# #### Data Provided:
#
# ●	The theoretical weekly operating cost model: W = $1,000 + $5X
#
# ●	Sample of 25 restaurants with a mean weekly cost of Rs. 3,050
#
# ●	Number of units produced in a week (X) follows a normal distribution with a mean (μ) of 600 units and a standard deviation (σ) of 25 units

# %% [markdown]
# #### Assignment Tasks:

# %% [markdown]
# ##### 1. State the Hypotheses statement:

# %% [markdown]
# ##### Hypotheses Statement
#
# Null Hypothesis (H₀):
#
# The weekly operating cost follows the given model (no increase).
#
# μ=1000+5X
#
# Alternative Hypothesis (H₁):
#
# The weekly operating cost is higher than the model suggests.
#
# μ>1000+5X

# %% [markdown]
# ##### 2. Calculate the Test Statistic:
#
# Use the following formula to calculate the test statistic(z):
#
# where:
#
# ●	ˉxˉ = sample mean weekly cost (Rs. 3,050)
#
# ●	μ = theoretical mean weekly cost according to the cost model (W = $1,000 + $5X for X = 600 units)
#
# ●	σ = 5*25 units
#
# ●	n = sample size (25 restaurants)

# %%
import math

# Given values
x_bar = 3050        # sample mean
X = 600             # units produced
mu = 1000 + 5 * X   # theoretical mean
sigma = 5 * 25      # standard deviation
n = 25              # sample size

# Calculate Z statistic
z = (x_bar - mu) / (sigma / math.sqrt(n))

# Output
print("Sample Mean (x̄):", x_bar)
print("Theoretical Mean (μ):", mu)
print("Standard Deviation (σ):", sigma)
print("Sample Size (n):", n)
print("Z-statistic:", z)
# Out:
# Sample Mean (x̄): 3050
# Theoretical Mean (μ): 4000
# Standard Deviation (σ): 125
# Sample Size (n): 25
# Z-statistic: -38.0

# %% [markdown]
# ##### 3. Determine the Probability and compare:
# Using the alpha level of 5% (α = 0.05),

# %%
from scipy.stats import norm

z = -38

# Right-tailed test
p_value = 1 - norm.cdf(z)

print("Z value:", z)
print("p-value:", p_value)

# Comparison
alpha = 0.05
if p_value <= alpha:
    print("Reject Null Hypothesis")
else:
    print("Fail to Reject Null Hypothesis")
# Out:
# Z value: -38
# p-value: 1.0
# Fail to Reject Null Hypothesis

# %% [markdown]
# ##### 4. Make a Decision:
#
# Compare the test statistic with the critical value to decide whether to reject the null hypothesis.

# %%
from scipy.stats import norm

# Given values
z = -38
alpha = 0.05

# Critical value for right-tailed test
z_critical = norm.ppf(1 - alpha)

print("Z value:", z)
print("Critical Z value:", z_critical)

# Decision
if z > z_critical:
    print("Reject Null Hypothesis (H0)")
else:
    print("Fail to Reject Null Hypothesis (H0)")
# Out:
# Z value: -38
# Critical Z value: 1.6448536269514722
# Fail to Reject Null Hypothesis (H0)

# %% [markdown]
# ##### 5. Conclusion:
#
# Based on the decision in step 4, conclude whether there is strong evidence to support the restaurant owners' claim that the weekly operating costs are higher than the model suggests.

# %% [markdown]
# ##### based on the results of the hypothesis test, we fail to reject the null hypothesis (H₀).
#
# This means there is no strong statistical evidence to support the restaurant owners' claim that the weekly operating costs are higher than the model suggests.
#
# -> In fact, the sample data indicates that the observed costs are lower than the expected cost, not higher.
